# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

pd.set_option('display.precision', 2)

# %%
df = pd.read_csv('nbastats.csv')

# %%
df.shape
# Out:
# (282, 26)

# %%
df.head()
# Out:
#   Position                Players   PPG   RPG  APG  SPG  BPG   FGM   FGA  \
# 0       PF  Giannis Antetokounmpo  32.3   9.5  7.8  3.6  3.8  13.9  15.6
# 1       SG         Michael Jordan  35.2   5.2  8.3  3.4  1.3  14.3  16.3
# 2       SF             Larry Bird  30.0   7.4  8.9  0.6  2.1  10.9  12.0
# 3       SF           Kevin Durant  34.8   7.0  6.0  1.3  1.3  13.8  15.7
# 4        C         David Robinson  27.3  12.6  5.3  1.4  3.6  11.7  13.1
#
#      FG %  ...  FTM  Scoring Rating Rebound Rating  Assist Rating  \
# 0  89.13%  ...  2.4           30.44          27.29          28.26
# 1  87.64%  ...  2.3           32.33          18.98          23.84
# 2  90.99%  ...  0.7           26.96          24.10          28.91
# 3  87.50%  ...  2.0           31.58          22.70          19.39
# 4  89.62%  ...  1.8           25.58          31.61          21.00
#
#    Steal Rating Block Rating  Efficiency Rating  2-Pointer Rating  \
# ...

# %%
df.columns
# Out:
# Index(['Position', 'Players', 'PPG', 'RPG', 'APG', 'SPG', 'BPG', 'FGM', 'FGA',
#        'FG %', '2PM', '2PA', '2PT%', '3PM', '3PA', '3PT %', 'FTM',
#        'Scoring Rating', 'Rebound Rating', 'Assist Rating', 'Steal Rating',
#        'Block Rating', 'Efficiency Rating', '2-Pointer Rating',
#        '3-Poimter Rating', 'Overall Rating'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Position              object
# Players               object
# PPG                  float64
# RPG                  float64
# APG                  float64
# SPG                  float64
# BPG                  float64
# FGM                  float64
# FGA                  float64
# FG %                  object
# 2PM                  float64
# 2PA                  float64
# 2PT%                  object
# 3PM                  float64
# 3PA                  float64
# 3PT %                 object
# FTM                  float64
# Scoring Rating       float64
# Rebound Rating       float64
# Assist Rating        float64
# Steal Rating         float64
# Block Rating         float64
# Efficiency Rating    float64
# 2-Pointer Rating     float64
# 3-Poimter Rating     float64
# Overall Rating       float64
# dtype: object

# %%
non_null_counts = df.count()

print("\nNon-Null Value Counts:\n")
print(non_null_counts)
# Out:
# Non-Null Value Counts:
#
# Position             282
# Players              282
# PPG                  282
# RPG                  282
# APG                  282
# SPG                  282
# BPG                  282
# FGM                  282
# FGA                  282
# FG %                 282
# 2PM                  282
# 2PA                  282
# 2PT%                 282
# 3PM                  282
# 3PA                  282
# 3PT %                282
# FTM                  282
# Scoring Rating       282
# Rebound Rating       282
# Assist Rating        282
# Steal Rating         282
# Block Rating         282
# Efficiency Rating    282
# 2-Pointer Rating     282
# 3-Poimter Rating     282
# Overall Rating       282
# dtype: int64

# %%
desc_stats = df.describe()

print("Descriptive Statistics:\n")
print(desc_stats)
# Out:
# Descriptive Statistics:
#
#           PPG     RPG     APG     SPG     BPG     FGM     FGA     2PM     2PA  \
# count  282.00  282.00  282.00  282.00  282.00  282.00  282.00  282.00  282.00
# mean    11.89    3.82    3.63    1.07    0.98    4.74    5.62    2.83    3.17
# std      5.96    2.42    1.98    1.05    0.91    2.43    2.75    1.94    2.12
# min      3.90    0.60    1.30    0.00    0.00    1.70    2.00    0.20    0.40
# 25%      7.80    1.90    2.30    0.30    0.30    3.10    3.70    1.60    1.80
# 50%     10.35    3.00    3.00    0.60    0.65    4.10    4.90    2.30    2.60
# 75%     14.05    5.20    4.20    1.48    1.30    5.70    6.85    3.50    3.80
# max     35.20   12.60   11.30    5.00    4.80   14.30   16.30   10.40   11.40
#
#           3PM  ...     FTM  Scoring Rating  Rebound Rating  Assist Rating  \
# count  282.00  ...  282.00          282.00          282.00         282.00
# mean     1.92  ...    0.47           10.20           11.47          11.48
# ...

# %%
df = df.rename(columns={'Position': 'position'
                      ,'Players': 'players'
                      ,'PPG': 'ppg'
                      ,'RPG': 'rpg'
                      ,'APG': 'apg'
                      ,'SPG': 'spg'
                      ,'BPG': 'bpg'
                      ,'FGM': 'fgm'
                      ,'FGA': 'fga'
                      ,'FG %': 'fgper'
                      ,'FTM': 'ftm'
                      ,'2PM': '2pm'
                      ,'2PA': '2pa'
                      ,'2PT%': '2ptper'
                      ,'3PM': '3pm'
                      ,'3PA': '3pa'
                      ,'3PT%': '3ptper'
                      ,'Scoring Rating': 'scoring_rating'
                      ,'Rebound Rating': 'rebound_rating'
                      ,'Assist Rating': 'assist_rating'
                      ,'Steal Rating': 'steal_rating'
                      ,'Block Rating': 'block_rating'
                      ,'Efficiency Rating': 'efficiency_rating'
                      ,'2-Pointer Rating': '2pointer_rating'
                      ,'3-Poimter Rating': '3pointer_rating'
                      ,'Overall Rating': 'overall_rating'
                      })

df.head()
# Out:
#   position                players   ppg   rpg  apg  spg  bpg   fgm   fga  \
# 0       PF  Giannis Antetokounmpo  32.3   9.5  7.8  3.6  3.8  13.9  15.6
# 1       SG         Michael Jordan  35.2   5.2  8.3  3.4  1.3  14.3  16.3
# 2       SF             Larry Bird  30.0   7.4  8.9  0.6  2.1  10.9  12.0
# 3       SF           Kevin Durant  34.8   7.0  6.0  1.3  1.3  13.8  15.7
# 4        C         David Robinson  27.3  12.6  5.3  1.4  3.6  11.7  13.1
#
#     fgper  ...  ftm  scoring_rating rebound_rating  assist_rating  \
# 0  89.13%  ...  2.4           30.44          27.29          28.26
# 1  87.64%  ...  2.3           32.33          18.98          23.84
# 2  90.99%  ...  0.7           26.96          24.10          28.91
# 3  87.50%  ...  2.0           31.58          22.70          19.39
# 4  89.62%  ...  1.8           25.58          31.61          21.00
#
#    steal_rating block_rating  efficiency_rating  2pointer_rating  \
# ...

# %%
import matplotlib.pyplot as plt
import os
# extra code - the next 5 lines define the default font sizes 
plt.rc('font', size=14)
plt.rc('axes', labelsize=8, titlesize=10)
plt.rc('legend', fontsize=8)
plt.rc('xtick', labelsize=8)
plt.rc('ytick', labelsize=8)

df.hist (bins=50, figsize=(24, 16))

#save_fig("attribute_histogram_plots") # extra code

plt.show()

# %% [markdown]
# 1. Statistical measurements of each of the features of the data.
#
# The data presented collates the performance of every player and analyzes the data to form a histogram that summarizes a player's performance relative to their intended roles and positions. The data rewards players by increasing their rating by performing well and demerits the rating of players who do not perform well.

# %% [markdown]
# 2. Create a graphic representation of three of the most interesting features and describe why is it significant for you.
#
# Based on what our group has discussed, we have determined the three most interesting features of the graphic and why I personally agree with their decision.
#
# ![Alt text](https://file%2B.vscode-resource.vscode-cdn.net/c%3A/Users/jkobe/jupyter/Jun2Act/Picture1.png?version%3D1685715212446)
#
# The PPG or Points Per Game articulates the scoring ability of a player. This graphic is significant for me as it showcases which players are likely to lead their team to victory.
#
# ![Alt text](https://file%2B.vscode-resource.vscode-cdn.net/c%3A/Users/jkobe/jupyter/Jun2Act/Picture2.png?version%3D1685715395947)
#
# The effeciency rating describes a players ability to score. Not to be confused with the first picture as the former talks about how much a player can score in a single game. This histogram breaks down how effecient players are at scoring for their team, which is significant because despite having designated positions and roles for each player, they may also outperform their intended instruction and help their team to victory.
#
# ![Alt text](https://file%2B.vscode-resource.vscode-cdn.net/c%3A/Users/jkobe/jupyter/Jun2Act/Picture3.png?version%3D1685715592948)
#
# The overall rating collates all the ratings, including the previously mentioned two, to summarize a player's performance. It significance lies on taking into account all the other ratings to simplify which players are likely to perform the best.

# %% [markdown]
# 3. Determine if the data has the potential for machine learning goals and what applications you think can use this data.
#
# The most obvious answer to this question is to have it as reference for any basketball video game. This type of data may also serve as a basis to how well a player will (or should ideally) perform in the game. This data, since it derives from a game, which derives its characters from real people, may also be used to better position a player into a more suitable role for them.

# %% [markdown]
# 4. Discuss potential issues and anomalies seen in the data (missing data, outliers, etc.).
#
# Apart from potential importing issues, outliers play a big factor into the results of a player's performance. As mentioned previously, certain players outperform their roles, which over-rewards them with a rating higher than intended. These types of outliers can severely affect the balance of the data and the gameplay if it is exploited. To narrate my groupmate's example (due to my low knowledge in the game of basketball and how these numbers are reached) the player Larry Bird is a "small forward position" player that was able to hit 7.2 3-pointers made per game at 87.34 efficiency, which rewards with an outlier of 44.84 3-pointer rating. Another example is Ben Simmons, who plays the "power forward" position, averaging 10.9 assists per game which rewards him with 39.51 assist rating. Those are some of the examples of the outliers that this data set has which could potentially offset the intended goal of the data.

# %% [markdown]
# 5. Why do you think knowing and exploring data is important before going through and applying machine learning algorithms?
#
# Taking back from what was discussed in the previous question, understanding that data may sometimes become oversaturated, that to take it as face value may lead to inconsitencies in the results, it is important to be data literate, and actually understand what type of data you are dealing with. A machine learning algorithm can only base off of your data, which makes it important to make sure that you understand the whys and hows of the data's results.
